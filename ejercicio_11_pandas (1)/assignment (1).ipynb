# %%
import pandas as pd

# %%
df=pd.read_csv('athlete_events.csv')

# %%
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %% [markdown]
# ¿Quién es el más jóven que haya ganado medalla de oro?
# ¿Quién es el más jóven que haya ganado medalla de plata?
# ¿Quién es el más jóven que haya ganado medalla de bronce?
# ¿Quién ha ganado más medallas?

# %%
oro=df[df['Medal']=='Gold']
oro
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...

# %%
edadOro=oro['Age'].min()
edadOro
# Out:
# 13.0

# %%
jovenoro=df[df['Age']==edadOro]
jovenoro
# Out:
#             ID                                           Name Sex   Age  \
# 5224      2962                                  Zsuzsa Almssy   F  13.0
# 7500      4191  Tojohanitra Tokin'aina Andriamanjatoarimanana   F  13.0
# 11209     6129                                Eleni Avlonitou   F  13.0
# 11210     6129                                Eleni Avlonitou   F  13.0
# 11211     6129                                Eleni Avlonitou   F  13.0
# ...        ...                                            ...  ..   ...
# 265497  132855                        Wei Ling "Joscelin" Yeo   F  13.0
# 265498  132855                        Wei Ling "Joscelin" Yeo   F  13.0
# 265499  132855                        Wei Ling "Joscelin" Yeo   F  13.0
# 265800  132998                            Yip Tsz Wa "Yvonne"   F  13.0
# 268602  134381                                    Klaus Zerta   M  13.0
#
#         Height  Weight        Team  NOC        Games  Year  Season       City  \
# ...

# %%
#df[df['Age']==edadOro & df['Medal']=='Gold']
df[oro & jovenoro]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     264         #  (xint or xbool) and (yint or bool)
# --> 265         result = op(x, y)
#     266     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-303dee40ef03> in <module>
#       1 #df[df['Age']==edadOro & df['Medal']=='Gold']
# ----> 2 df[oro & jovenoro]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ...

# %%
empleados[empleados['First Name']=='Maria']
